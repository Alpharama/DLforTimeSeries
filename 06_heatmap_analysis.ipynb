# %% [markdown]
# # Notebook 07 — Heatmap Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

dfs = []
for nb in ['nb02', 'nb03', 'nb04', 'nb05']:
    path = Path(f'results_csv/{nb}_results.csv')
    if path.exists():
        dfs.append(pd.read_csv(path))
    else:
        print(f'Missing: {path}')

df_all = pd.concat(dfs, ignore_index=True)
print(f'{len(df_all)} rows loaded')
display(df_all.head(10))
# Out:
# 112 rows loaded
#   finetuning              pooling  patch_size  accuracy  macro_recall  \
# 0  02_Frozen                 Mean           8  0.611517      0.363178
# 1  02_Frozen     Attention-shared           8  0.596918      0.358135
# 2  02_Frozen      Attention-indep           8  0.603812      0.355907
# 3  02_Frozen           MHA-shared           8  0.618816      0.376281
# 4  02_Frozen            MHA-indep           8  0.611922      0.380971
# 5  02_Frozen  Hierarchical-shared           8  0.575020      0.325842
# 6  02_Frozen   Hierarchical-indep           8  0.611517      0.357908
# 7  02_Frozen                 Mean          16  0.618005           NaN
# 8  02_Frozen     Attention-shared          16  0.608273           NaN
# 9  02_Frozen      Attention-indep          16  0.609489           NaN
#
#    macro_f1
# 0  0.376169
# 1  0.372340
# 2  0.366543
# 3  0.388403
# 4  0.396139
# 5  0.315856
# 6  0.358963
# 7       NaN
# 8       NaN
# 9       NaN

# %%
FINETUNING_ORDER = ['02_Frozen', '03_MaskFT', '04_FullFT', '05_LoRA']
FT_LABELS = {'02_Frozen': 'Frozen', '03_MaskFT': 'MaskFT', '04_FullFT': 'FullFT', '05_LoRA': 'LoRA'}

POOLING_ORDER = [
    'Mean',
    'Attention-shared', 'Attention-indep',
    'MHA-shared',       'MHA-indep',
    'Hierarchical-shared', 'Hierarchical-indep',
]
GROUP_BOUNDARIES = [1, 3, 5]

PATCH_SIZES = [8, 16, 32, 64]

sns.set_theme(style='whitegrid', font_scale=1.05)


def draw_heatmap(ax, pivot, cmap, vmin, vmax, metric_label):
    mask  = pivot.isnull()
    annot = pivot.copy().astype(object)
    annot[mask] = ''
    sns.heatmap(pivot.astype(float), ax=ax, annot=annot, fmt='',
                cmap=cmap, vmin=vmin, vmax=vmax,
                linewidths=0.5, linecolor='white',
                cbar_kws={'label': metric_label, 'shrink': 0.7}, mask=mask)
    for t in ax.texts:
        try: t.set_text(f'{float(t.get_text()):.3f}')
        except ValueError: pass
    for b in GROUP_BOUNDARIES:
        ax.axhline(b, color='#333333', linewidth=1.5)
    ax.tick_params(axis='x', rotation=30)
    ax.tick_params(axis='y', rotation=0)

# %% [markdown]
# ## Patch Size = 8 — Accuracy & Macro Recall

# %%
df_8 = df_all[df_all['patch_size'] == 8].copy()

for metric, label, vmin, vmax, cmap, fname in [
    ('accuracy',    'Accuracy',    0.55, 0.70, 'YlOrRd', 'results_csv/heatmap_patch8_accuracy.png'),
    ('macro_recall','Macro Recall',0.30, 0.42, 'YlGnBu', 'results_csv/heatmap_patch8_recall.png'),
]:
    pivot = (df_8.pivot_table(index='pooling', columns='finetuning', values=metric, aggfunc='first')
               .reindex(index=POOLING_ORDER, columns=FINETUNING_ORDER))
    pivot.columns = [FT_LABELS[c] for c in pivot.columns]

    fig, ax = plt.subplots(figsize=(10, 7))
    draw_heatmap(ax, pivot, cmap, vmin, vmax, label)
    ax.set_title(f'Patch 8  |  {label}', fontsize=13, fontweight='bold', pad=10)
    ax.set_xlabel('Fine-tuning strategy')
    ax.set_ylabel('Pooling head')
    plt.suptitle('Moirai Classification — Patch Size 8  (MHA-64 heads)', fontsize=13, fontweight='bold', y=1.01)
    plt.tight_layout()
    plt.savefig(fname, dpi=150, bbox_inches='tight')
    plt.show()

# %% [markdown]
# ## Accuracy across Patch Sizes (8, 16, 32, 64)

# %%
fig, axes = plt.subplots(2, 2, figsize=(19, 18))

for ax, patch in zip(axes.flatten(), PATCH_SIZES):
    df_p = df_all[df_all['patch_size'] == patch].copy()
    pivot = (df_p.pivot_table(index='pooling', columns='finetuning', values='accuracy', aggfunc='first')
               .reindex(index=POOLING_ORDER, columns=FINETUNING_ORDER))
    pivot.columns = [FT_LABELS[c] for c in pivot.columns]
    draw_heatmap(ax, pivot, 'YlOrRd', 0.55, 0.70, 'Accuracy')
    ax.set_title(f'Patch {patch}  |  Accuracy', fontsize=12, fontweight='bold', pad=8)
    ax.set_xlabel('Fine-tuning strategy')
    ax.set_ylabel('Pooling head')

plt.suptitle('Moirai Classification — Accuracy by Patch Size', fontsize=13, fontweight='bold')
plt.tight_layout()
plt.savefig('results_csv/heatmap_all_patches.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## MHA — Number of Heads vs Fine-tuning Strategy (patch = 8)
#
# Rows: number of attention heads (4 → 384).
# Columns: Frozen / MaskFT / FullFT / LoRA r=8 / LoRA r=64.
# LoRA results are only available for MHA-64.

# %%
HEADS    = [4, 8, 16, 32, 64, 128, 384]
MODES    = ['shared_context', 'independent_context']
FT_ORDER = ['Frozen', 'MaskFT', 'FullFT', 'LoRA r=8', 'LoRA r=64']

# nb02: no Model column — reconstruct index from insertion order
nb02_raw = pd.read_csv('results_csv/nb02_patch_8_metrics.csv')
nb02_raw.index = (
    ['Mean Pooling']
    + [f'Attention ({m})' for m in MODES]
    + [f'MHA-{h} ({m})' for h in HEADS for m in MODES]
    + [f'Hierarchical ({m})' for m in MODES]
)[:len(nb02_raw)]

nb03_raw = pd.read_csv('results_csv/nb03_patch_8_metrics.csv', index_col=0)
nb04_raw = pd.read_csv('results_csv/nb04_patch_8_metrics.csv', index_col=0)
nb05_raw = pd.read_csv('results_csv/nb05_patch_8_metrics.csv', index_col=0)

records = []

def collect(raw_df, ft_label):
    for h in HEADS:
        for mode in MODES:
            lbl = f'MHA-{h} ({mode})'
            if lbl in raw_df.index:
                row = raw_df.loc[lbl]
                records.append({
                    'n_heads': h, 'mode': mode, 'finetuning': ft_label,
                    'accuracy':     pd.to_numeric(row['Accuracy'],      errors='coerce'),
                    'macro_recall': pd.to_numeric(row['Macro Recall'],  errors='coerce'),
                })

def collect_lora(raw_df, rank):
    """Collect MHA results for ALL head counts with a given LoRA rank."""
    for h in HEADS:
        for mode in MODES:
            lbl = f'MHA-{h} ({mode}) LoRA r={rank}'
            if lbl in raw_df.index:
                row = raw_df.loc[lbl]
                records.append({
                    'n_heads': h, 'mode': mode, 'finetuning': f'LoRA r={rank}',
                    'accuracy':     pd.to_numeric(row['Accuracy'],      errors='coerce'),
                    'macro_recall': pd.to_numeric(row['Macro Recall'],  errors='coerce'),
                })

collect(nb02_raw, 'Frozen')
collect(nb03_raw, 'MaskFT')
collect(nb04_raw, 'FullFT')
collect_lora(nb05_raw, 8)
collect_lora(nb05_raw, 64)

df_mha = pd.DataFrame(records)
print(f'{len(df_mha)} MHA records')
display(df_mha.pivot_table(index=['mode', 'n_heads'], columns='finetuning', values='accuracy').round(4))
# Out:
# 70 MHA records
# finetuning                   Frozen  FullFT  LoRA r=64  LoRA r=8  MaskFT
# mode                n_heads
# independent_context 4        0.6204  0.6436     0.6338    0.6233  0.6030
#                     8        0.6135  0.6387     0.6196    0.6306  0.6046
#                     16       0.6168  0.6395     0.6350    0.6249  0.6103
#                     32       0.6123  0.6395     0.6346    0.6261  0.6062
#                     64       0.6119  0.6350     0.6350    0.6241  0.6058
#                     128      0.6139  0.6334     0.6285    0.6249  0.6075
#                     384      0.6123  0.6354     0.6391    0.6172  0.6160
# shared_context      4        0.6139  0.6476     0.6367    0.6298  0.6071
#                     8        0.6079  0.6261     0.6212    0.6221  0.6026
#                     16       0.6176  0.6233     0.6391    0.6261  0.6180
#                     32       0.6115  0.6395     0.6334    0.6261  0.6184
#                     64       0.6188  0.6346     0.6326    0.6180  0.6083
#                     128      0.6192  0.6330     0.6180    0.6217  0.6067
#                     384      0.6184  0.6310     0.6184    0.6257  0.6030

# %%
MODE_LABELS = {'shared_context': 'Shared context', 'independent_context': 'Independent context'}

def mha_heatmap(metric, label, vmin, vmax, cmap, path):
    fig, axes = plt.subplots(1, 2, figsize=(16, 7), sharey=True)
    for ax, mode in zip(axes, MODES):
        pivot = (
            df_mha[df_mha['mode'] == mode]
            .pivot_table(index='n_heads', columns='finetuning', values=metric, aggfunc='first')
            .reindex(index=HEADS, columns=FT_ORDER)
        )
        mask  = pivot.isnull()
        annot = pivot.copy().astype(object)
        annot[mask] = ''
        sns.heatmap(pivot.astype(float), ax=ax, annot=annot, fmt='',
                    cmap=cmap, vmin=vmin, vmax=vmax,
                    linewidths=0.6, linecolor='white',
                    cbar_kws={'label': label, 'shrink': 0.75}, mask=mask)
        for t in ax.texts:
            try: t.set_text(f'{float(t.get_text()):.3f}')
            except ValueError: pass
        ax.axvline(3, color='#333333', linewidth=1.8, linestyle='--')
        ax.set_title(MODE_LABELS[mode], fontsize=12, fontweight='bold', pad=8)
        ax.set_xlabel('Fine-tuning strategy')
        ax.set_ylabel('Number of heads')
        ax.set_yticklabels([str(h) for h in HEADS])
        ax.tick_params(axis='x', rotation=25)
        ax.tick_params(axis='y', rotation=0)
    fig.suptitle(f'MHA — Heads vs Fine-tuning  |  {label}  (patch = 8)',
                 fontsize=13, fontweight='bold', y=1.02)
    plt.tight_layout()
    plt.savefig(path, dpi=150, bbox_inches='tight')
    plt.show()

mha_heatmap('accuracy',     'Accuracy',     0.55, 0.70, 'YlOrRd', 'results_csv/heatmap_mha_heads_accuracy.png')
mha_heatmap('macro_recall', 'Macro Recall', 0.30, 0.42, 'YlGnBu', 'results_csv/heatmap_mha_heads_recall.png')

# %% [markdown]
# ## LoRA / DoRA / AdaLoRA — Rank vs Method (patch = 8, Mean Pooling head)

# %%
RANKS   = [2, 4, 8, 16, 32, 64]
METHODS = ['LoRA', 'DoRA', 'AdaLoRA']

nb05 = pd.read_csv('results_csv/nb05_patch_8_metrics.csv', index_col=0)

lora_records = []
for method in METHODS:
    for r in RANKS:
        lbl = f'{method} r={r}'
        if lbl in nb05.index:
            row = nb05.loc[lbl]
            lora_records.append({
                'method': method, 'rank': r,
                'accuracy':     pd.to_numeric(row['Accuracy'],     errors='coerce'),
                'macro_recall': pd.to_numeric(row['Macro Recall'], errors='coerce'),
            })

df_lora = pd.DataFrame(lora_records)

for metric, label, vmin, vmax, cmap, fname in [
    ('accuracy',    'Accuracy',    0.55, 0.70, 'YlOrRd', 'results_csv/heatmap_lora_rank_accuracy.png'),
    ('macro_recall','Macro Recall',0.30, 0.42, 'YlGnBu', 'results_csv/heatmap_lora_rank_recall.png'),
]:
    pivot = (
        df_lora.pivot_table(index='rank', columns='method', values=metric, aggfunc='first')
               .reindex(index=RANKS, columns=METHODS)
    )
    annot = pivot.applymap(lambda x: f'{x:.3f}' if pd.notna(x) else '')

    fig, ax = plt.subplots(figsize=(7, 6))
    sns.heatmap(pivot.astype(float), ax=ax, annot=annot, fmt='',
                cmap=cmap, vmin=vmin, vmax=vmax,
                linewidths=0.6, linecolor='white',
                cbar_kws={'label': label, 'shrink': 0.75})
    ax.set_title(f'LoRA / DoRA / AdaLoRA — Rank vs Method  |  {label}', fontsize=12, fontweight='bold', pad=8)
    ax.set_xlabel('PEFT method')
    ax.set_ylabel('Rank')
    ax.tick_params(axis='x', rotation=0)
    ax.tick_params(axis='y', rotation=0)
    plt.suptitle('patch = 8, Mean Pooling head', fontsize=10, y=1.01)
    plt.tight_layout()
    plt.savefig(fname, dpi=150, bbox_inches='tight')
    plt.show()
# Out:
# /tmp/ipykernel_3818/3354343932.py:28: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   annot = pivot.applymap(lambda x: f'{x:.3f}' if pd.notna(x) else '')
# /tmp/ipykernel_3818/3354343932.py:28: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   annot = pivot.applymap(lambda x: f'{x:.3f}' if pd.notna(x) else '')

# %% [markdown]
# ## Repeated Comparison — Mean / Std / Min / Max (NB07)

# %%
df_nb07 = pd.read_csv('results_csv/nb07_results.csv')

METRICS = {'accuracy': 'Accuracy', 'macro_recall': 'Macro Recall'}

rows = []
for model, grp in df_nb07.groupby('model', sort=False):
    row = {'Model': model}
    for col, label in METRICS.items():
        vals = grp[col].values
        row[f'{label} mean'] = f'{vals.mean():.3f}'
        row[f'{label} std']  = f'{vals.std():.3f}'
        row[f'{label} min']  = f'{vals.min():.3f}'
        row[f'{label} max']  = f'{vals.max():.3f}'
    rows.append(row)

df_table = pd.DataFrame(rows).set_index('Model')
display(df_table)
# Out:
#                                        Accuracy mean Accuracy std  \
# Model
# FullFT p8 + MeanPooling                        0.643        0.009
# FullFT p8 + MHA (4 heads)                      0.640        0.007
# FullFT p8 + LoRA p64 + MeanPool Concat         0.647        0.006
# LoRA p64 + FullFT p8 + Cascade                 0.639        0.011
#
#                                        Accuracy min Accuracy max  \
# Model
# FullFT p8 + MeanPooling                       0.627        0.657
# FullFT p8 + MHA (4 heads)                     0.630        0.652
# FullFT p8 + LoRA p64 + MeanPool Concat        0.635        0.659
# LoRA p64 + FullFT p8 + Cascade                0.617        0.655
#
#                                        Macro Recall mean Macro Recall std  \
# Model
# FullFT p8 + MeanPooling                            0.378            0.012
# FullFT p8 + MHA (4 heads)                          0.373            0.013
# FullFT p8 + LoRA p64 + MeanPool Concat             0.380            0.009
# LoRA p64 + FullFT p8 + Cascade                     0.372            0.015
#
#                                        Macro Recall min Macro Recall max
# Model
# FullFT p8 + MeanPooling                           0.362            0.400
# FullFT p8 + MHA (4 heads)                         0.343            0.392
# FullFT p8 + LoRA p64 + MeanPool Concat            0.364            0.388
# LoRA p64 + FullFT p8 + Cascade                    0.341            0.394

# %% [markdown]
# ## Classification Reports — Best Seed per Model (NB07)

# %%
MODEL_NAMES_NB07 = [
    "FullFT p8 + MeanPooling",
    "FullFT p8 + MHA (4 heads)",
    "FullFT p8 + LoRA p64 + MeanPool Concat",
    "LoRA p64 + FullFT p8 + Cascade",
]

for name in MODEL_NAMES_NB07:
    safe_name = name.replace(" ", "_").replace("+", "").replace("(", "").replace(")", "")
    path = Path(f"results_csv/nb07_report_{safe_name}.csv")
    if not path.exists():
        print(f"Missing: {path}  (run NB07 classification report cell first)")
        continue
    df_rep = pd.read_csv(path, index_col=0).round(2)
    print(f"\n{'='*60}")
    print(f"{name}")
    print(f"{'='*60}")
    display(df_rep)
# Out:
# ============================================================
# FullFT p8 + MeanPooling
# ============================================================
#               precision  recall  f1-score  support
# 0                  0.67    0.36      0.47   124.00
# 1                  0.93    0.93      0.93   270.00
# 2                  0.53    0.29      0.37   382.00
# 3                  0.00    0.00      0.00    63.00
# 4                  0.00    0.00      0.00     7.00
# 5                  0.50    0.03      0.05    35.00
# 6                  0.23    0.15      0.18   153.00
# 7                  0.00    0.00      0.00    24.00
# 8                  0.81    0.91      0.86   313.00
# 9                  0.00    0.00      0.00    68.00
# 10                 0.87    0.98      0.92   121.00
# 11                 0.57    0.91      0.70   777.00
# 12                 0.79    0.75      0.77    77.00
# 13                 0.50    0.13      0.21    52.00
# accuracy           0.65    0.65      0.65     0.65
# macro avg          0.46    0.39      0.39  2466.00
# weighted avg       0.60    0.65      0.60  2466.00
# ============================================================
# FullFT p8 + MHA (4 heads)
# ============================================================
#               precision  recall  f1-score  support
# 0                  0.62    0.53      0.57   124.00
# 1                  0.85    0.96      0.90   270.00
# 2                  0.45    0.35      0.39   382.00
# 3                  0.00    0.00      0.00    63.00
# 4                  0.00    0.00      0.00     7.00
# 5                  0.00    0.00      0.00    35.00
# 6                  0.30    0.14      0.19   153.00
# 7                  0.00    0.00      0.00    24.00
# 8                  0.74    0.89      0.81   313.00
# 9                  0.00    0.00      0.00    68.00
# 10                 0.85    0.93      0.89   121.00
# 11                 0.60    0.86      0.71   777.00
# 12                 0.74    0.45      0.56    77.00
# 13                 0.33    0.13      0.19    52.00
# accuracy           0.64    0.64      0.64     0.64
# macro avg          0.39    0.38      0.37  2466.00
# weighted avg       0.57    0.64      0.59  2466.00
# ============================================================
# FullFT p8 + LoRA p64 + MeanPool Concat
# ============================================================
#               precision  recall  f1-score  support
# 0                  0.73    0.27      0.39   124.00
# 1                  0.94    0.89      0.91   270.00
# 2                  0.44    0.44      0.44   382.00
# 3                  0.00    0.00      0.00    63.00
# 4                  0.00    0.00      0.00     7.00
# 5                  0.00    0.00      0.00    35.00
# 6                  0.20    0.01      0.01   153.00
# 7                  0.00    0.00      0.00    24.00
# 8                  0.78    0.87      0.82   313.00
# 9                  0.00    0.00      0.00    68.00
# 10                 0.88    0.97      0.92   121.00
# 11                 0.57    0.88      0.69   777.00
# 12                 0.65    0.84      0.73    77.00
# 13                 0.67    0.12      0.20    52.00
# accuracy           0.64    0.64      0.64     0.64
# macro avg          0.42    0.38      0.37  2466.00
# weighted avg       0.58    0.64      0.58  2466.00
# ============================================================
# LoRA p64 + FullFT p8 + Cascade
# ============================================================
#               precision  recall  f1-score  support
# 0                  0.67    0.42      0.51   124.00
# 1                  0.89    0.93      0.91   270.00
# 2                  0.46    0.38      0.42   382.00
# 3                  0.00    0.00      0.00    63.00
# 4                  0.00    0.00      0.00     7.00
# 5                  0.00    0.00      0.00    35.00
# 6                  0.32    0.15      0.20   153.00
# 7                  0.00    0.00      0.00    24.00
# 8                  0.78    0.87      0.82   313.00
# 9                  0.10    0.01      0.03    68.00
# 10                 0.94    0.98      0.96   121.00
# 11                 0.58    0.86      0.69   777.00
# 12                 0.73    0.57      0.64    77.00
# 13                 0.47    0.13      0.21    52.00
# accuracy           0.64    0.64      0.64     0.64
# macro avg          0.42    0.38      0.39  2466.00
# weighted avg       0.58    0.64      0.60  2466.00

# %% [markdown]
# ## Recall par classe — Comparaison des modèles (NB07, seed 42)

# %%
MODEL_NAMES_NB07 = [
    "FullFT p8 + MeanPooling",
    "FullFT p8 + MHA (4 heads)",
    "FullFT p8 + LoRA p64 + MeanPool Concat",
    "LoRA p64 + FullFT p8 + Cascade",
]

recall_cols = {}
support = None
for name in MODEL_NAMES_NB07:
    safe_name = name.replace(" ", "_").replace("+", "").replace("(", "").replace(")", "")
    path = Path(f"results_csv/nb07_report_{safe_name}.csv")
    if not path.exists():
        print(f"Missing: {path}  (run NB07 classification report cell first)")
        continue
    df_rep = pd.read_csv(path, index_col=0)
    class_rows = df_rep[pd.to_numeric(df_rep.index, errors='coerce').notna()]
    recall_cols[name] = class_rows["recall"].astype(float)
    if support is None:
        support = class_rows["support"].astype(int)

df_recall = pd.DataFrame(recall_cols).round(2)
df_recall.insert(0, "Effectif", support)
df_recall.index.name = "Classe"
df_recall.index = df_recall.index.astype(int)
df_recall = df_recall.sort_index()

print("Recall par classe (seed 42) :")
display(df_recall)
# Out:
# Recall par classe (seed 42) :
#         Effectif  FullFT p8 + MeanPooling  FullFT p8 + MHA (4 heads)  \
# Classe
# 0            124                     0.36                       0.53
# 1            270                     0.93                       0.96
# 2            382                     0.29                       0.35
# 3             63                     0.00                       0.00
# 4              7                     0.00                       0.00
# 5             35                     0.03                       0.00
# 6            153                     0.15                       0.14
# 7             24                     0.00                       0.00
# 8            313                     0.91                       0.89
# 9             68                     0.00                       0.00
# 10           121                     0.98                       0.93
# 11           777                     0.91                       0.86
# 12            77                     0.75                       0.45
# 13            52                     0.13                       0.13
#
#         FullFT p8 + LoRA p64 + MeanPool Concat  LoRA p64 + FullFT p8 + Cascade
# Classe
# 0                                         0.27                            0.42
# 1                                         0.89                            0.93
# 2                                         0.44                            0.38
# 3                                         0.00                            0.00
# 4                                         0.00                            0.00
# 5                                         0.00                            0.00
# 6                                         0.01                            0.15
# 7                                         0.00                            0.00
# 8                                         0.87                            0.87
# 9                                         0.00                            0.01
# 10                                        0.97                            0.98
# 11                                        0.88                            0.86
# 12                                        0.84                            0.57
# 13                                        0.12                            0.13

# %% [markdown]
# ## Export LaTeX

# %%
def print_latex(title, df, **kwargs):
    print(f"% ── {title} ──────────────────────────────────────")
    print(df.to_latex(**kwargs))
    print()

# ── 1. Résumé repeated comparison (mean / std / min / max) ──────────────────
print_latex(
    "Repeated Comparison — Mean / Std / Min / Max",
    df_table,
    escape=False,
    column_format="l" + "r" * len(df_table.columns),
)

# ── 2. Classification reports par modèle ────────────────────────────────────
for name in MODEL_NAMES_NB07:
    safe_name = name.replace(" ", "_").replace("+", "").replace("(", "").replace(")", "")
    path = Path(f"results_csv/nb07_report_{safe_name}.csv")
    if not path.exists():
        continue
    df_rep = pd.read_csv(path, index_col=0).round(2)
    print_latex(
        f"Classification Report — {name}",
        df_rep,
        escape=False,
        column_format="l" + "r" * len(df_rep.columns),
    )

# ── 3. Recall par classe + effectif ─────────────────────────────────────────
print_latex(
    "Recall par classe",
    df_recall,
    escape=False,
    column_format="l" + "r" * len(df_recall.columns),
)
# Out:
# % ── Repeated Comparison — Mean / Std / Min / Max ──────────────────────────────────────
# \begin{tabular}{lrrrrrrrr}
# \toprule
#  & Accuracy mean & Accuracy std & Accuracy min & Accuracy max & Macro Recall mean & Macro Recall std & Macro Recall min & Macro Recall max \\
# Model &  &  &  &  &  &  &  &  \\
# \midrule
# FullFT p8 + MeanPooling & 0.643 & 0.009 & 0.627 & 0.657 & 0.378 & 0.012 & 0.362 & 0.400 \\
# FullFT p8 + MHA (4 heads) & 0.640 & 0.007 & 0.630 & 0.652 & 0.373 & 0.013 & 0.343 & 0.392 \\
# FullFT p8 + LoRA p64 + MeanPool Concat & 0.647 & 0.006 & 0.635 & 0.659 & 0.380 & 0.009 & 0.364 & 0.388 \\
# LoRA p64 + FullFT p8 + Cascade & 0.639 & 0.011 & 0.617 & 0.655 & 0.372 & 0.015 & 0.341 & 0.394 \\
# \bottomrule
# \end{tabular}
#
#
# % ── Classification Report — FullFT p8 + MeanPooling ──────────────────────────────────────
# \begin{tabular}{lrrrr}
# \toprule
#  & precision & recall & f1-score & support \\
# \midrule
# 0 & 0.670000 & 0.360000 & 0.470000 & 124.000000 \\
# 1 & 0.930000 & 0.930000 & 0.930000 & 270.000000 \\
# 2 & 0.530000 & 0.290000 & 0.370000 & 382.000000 \\
# 3 & 0.000000 & 0.000000 & 0.000000 & 63.000000 \\
# 4 & 0.000000 & 0.000000 & 0.000000 & 7.000000 \\
# 5 & 0.500000 & 0.030000 & 0.050000 & 35.000000 \\
# 6 & 0.230000 & 0.150000 & 0.180000 & 153.000000 \\
# 7 & 0.000000 & 0.000000 & 0.000000 & 24.000000 \\
# 8 & 0.810000 & 0.910000 & 0.860000 & 313.000000 \\
# 9 & 0.000000 & 0.000000 & 0.000000 & 68.000000 \\
# 10 & 0.870000 & 0.980000 & 0.920000 & 121.000000 \\
# 11 & 0.570000 & 0.910000 & 0.700000 & 777.000000 \\
# 12 & 0.790000 & 0.750000 & 0.770000 & 77.000000 \\
# 13 & 0.500000 & 0.130000 & 0.210000 & 52.000000 \\
# accuracy & 0.650000 & 0.650000 & 0.650000 & 0.650000 \\
# macro avg & 0.460000 & 0.390000 & 0.390000 & 2466.000000 \\
# weighted avg & 0.600000 & 0.650000 & 0.600000 & 2466.000000 \\
# \bottomrule
# \end{tabular}
#
#
# % ── Classification Report — FullFT p8 + MHA (4 heads) ──────────────────────────────────────
# \begin{tabular}{lrrrr}
# \toprule
#  & precision & recall & f1-score & support \\
# \midrule
# 0 & 0.620000 & 0.530000 & 0.570000 & 124.000000 \\
# 1 & 0.850000 & 0.960000 & 0.900000 & 270.000000 \\
# 2 & 0.450000 & 0.350000 & 0.390000 & 382.000000 \\
# 3 & 0.000000 & 0.000000 & 0.000000 & 63.000000 \\
# 4 & 0.000000 & 0.000000 & 0.000000 & 7.000000 \\
# 5 & 0.000000 & 0.000000 & 0.000000 & 35.000000 \\
# 6 & 0.300000 & 0.140000 & 0.190000 & 153.000000 \\
# 7 & 0.000000 & 0.000000 & 0.000000 & 24.000000 \\
# 8 & 0.740000 & 0.890000 & 0.810000 & 313.000000 \\
# 9 & 0.000000 & 0.000000 & 0.000000 & 68.000000 \\
# 10 & 0.850000 & 0.930000 & 0.890000 & 121.000000 \\
# 11 & 0.600000 & 0.860000 & 0.710000 & 777.000000 \\
# 12 & 0.740000 & 0.450000 & 0.560000 & 77.000000 \\
# 13 & 0.330000 & 0.130000 & 0.190000 & 52.000000 \\
# accuracy & 0.640000 & 0.640000 & 0.640000 & 0.640000 \\
# macro avg & 0.390000 & 0.380000 & 0.370000 & 2466.000000 \\
# weighted avg & 0.570000 & 0.640000 & 0.590000 & 2466.000000 \\
# \bottomrule
# \end{tabular}
#
#
# % ── Classification Report — FullFT p8 + LoRA p64 + MeanPool Concat ──────────────────────────────────────
# \begin{tabular}{lrrrr}
# \toprule
#  & precision & recall & f1-score & support \\
# \midrule
# 0 & 0.730000 & 0.270000 & 0.390000 & 124.000000 \\
# 1 & 0.940000 & 0.890000 & 0.910000 & 270.000000 \\
# 2 & 0.440000 & 0.440000 & 0.440000 & 382.000000 \\
# 3 & 0.000000 & 0.000000 & 0.000000 & 63.000000 \\
# 4 & 0.000000 & 0.000000 & 0.000000 & 7.000000 \\
# 5 & 0.000000 & 0.000000 & 0.000000 & 35.000000 \\
# 6 & 0.200000 & 0.010000 & 0.010000 & 153.000000 \\
# 7 & 0.000000 & 0.000000 & 0.000000 & 24.000000 \\
# 8 & 0.780000 & 0.870000 & 0.820000 & 313.000000 \\
# 9 & 0.000000 & 0.000000 & 0.000000 & 68.000000 \\
# 10 & 0.880000 & 0.970000 & 0.920000 & 121.000000 \\
# 11 & 0.570000 & 0.880000 & 0.690000 & 777.000000 \\
# 12 & 0.650000 & 0.840000 & 0.730000 & 77.000000 \\
# 13 & 0.670000 & 0.120000 & 0.200000 & 52.000000 \\
# accuracy & 0.640000 & 0.640000 & 0.640000 & 0.640000 \\
# macro avg & 0.420000 & 0.380000 & 0.370000 & 2466.000000 \\
# weighted avg & 0.580000 & 0.640000 & 0.580000 & 2466.000000 \\
# \bottomrule
# \end{tabular}
#
#
# % ── Classification Report — LoRA p64 + FullFT p8 + Cascade ──────────────────────────────────────
# \begin{tabular}{lrrrr}
# \toprule
#  & precision & recall & f1-score & support \\
# \midrule
# 0 & 0.670000 & 0.420000 & 0.510000 & 124.000000 \\
# 1 & 0.890000 & 0.930000 & 0.910000 & 270.000000 \\
# 2 & 0.460000 & 0.380000 & 0.420000 & 382.000000 \\
# 3 & 0.000000 & 0.000000 & 0.000000 & 63.000000 \\
# 4 & 0.000000 & 0.000000 & 0.000000 & 7.000000 \\
# 5 & 0.000000 & 0.000000 & 0.000000 & 35.000000 \\
# 6 & 0.320000 & 0.150000 & 0.200000 & 153.000000 \\
# 7 & 0.000000 & 0.000000 & 0.000000 & 24.000000 \\
# 8 & 0.780000 & 0.870000 & 0.820000 & 313.000000 \\
# 9 & 0.100000 & 0.010000 & 0.030000 & 68.000000 \\
# 10 & 0.940000 & 0.980000 & 0.960000 & 121.000000 \\
# 11 & 0.580000 & 0.860000 & 0.690000 & 777.000000 \\
# 12 & 0.730000 & 0.570000 & 0.640000 & 77.000000 \\
# 13 & 0.470000 & 0.130000 & 0.210000 & 52.000000 \\
# accuracy & 0.640000 & 0.640000 & 0.640000 & 0.640000 \\
# macro avg & 0.420000 & 0.380000 & 0.390000 & 2466.000000 \\
# weighted avg & 0.580000 & 0.640000 & 0.600000 & 2466.000000 \\
# \bottomrule
# \end{tabular}
#
#
# % ── Recall par classe ──────────────────────────────────────
# \begin{tabular}{lrrrrr}
# \toprule
#  & Effectif & FullFT p8 + MeanPooling & FullFT p8 + MHA (4 heads) & FullFT p8 + LoRA p64 + MeanPool Concat & LoRA p64 + FullFT p8 + Cascade \\
# Classe &  &  &  &  &  \\
# \midrule
# 0 & 124 & 0.360000 & 0.530000 & 0.270000 & 0.420000 \\
# 1 & 270 & 0.930000 & 0.960000 & 0.890000 & 0.930000 \\
# 2 & 382 & 0.290000 & 0.350000 & 0.440000 & 0.380000 \\
# 3 & 63 & 0.000000 & 0.000000 & 0.000000 & 0.000000 \\
# 4 & 7 & 0.000000 & 0.000000 & 0.000000 & 0.000000 \\
# 5 & 35 & 0.030000 & 0.000000 & 0.000000 & 0.000000 \\
# 6 & 153 & 0.150000 & 0.140000 & 0.010000 & 0.150000 \\
# 7 & 24 & 0.000000 & 0.000000 & 0.000000 & 0.000000 \\
# 8 & 313 & 0.910000 & 0.890000 & 0.870000 & 0.870000 \\
# 9 & 68 & 0.000000 & 0.000000 & 0.000000 & 0.010000 \\
# 10 & 121 & 0.980000 & 0.930000 & 0.970000 & 0.980000 \\
# 11 & 777 & 0.910000 & 0.860000 & 0.880000 & 0.860000 \\
# 12 & 77 & 0.750000 & 0.450000 & 0.840000 & 0.570000 \\
# 13 & 52 & 0.130000 & 0.130000 & 0.120000 & 0.130000 \\
# \bottomrule
# \end{tabular}
